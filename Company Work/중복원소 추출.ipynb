# %%
import pandas as pd

a = []
for i in range(100000):
    a.append(i)
print(300000 * 300000)
cnt = 0
dup = []
for i in range(len(a)):
    for j in range(len(a)):
        cnt += 1
        if i != j:
            if a[i] == a[j]:
                dup.append(a[j])
        
        if cnt % 10 == 0:
            print("전체 진행도 : ", cnt, "회, ",cnt / (len(a) * len(a)) )

print(dup)
# Out:
# 90000000000
# 전체 진행도 :  10 회,  1e-09
# 전체 진행도 :  20 회,  2e-09
# 전체 진행도 :  30 회,  3e-09
# 전체 진행도 :  40 회,  4e-09
# 전체 진행도 :  50 회,  5e-09
# 전체 진행도 :  60 회,  6e-09
# 전체 진행도 :  70 회,  7e-09
# 전체 진행도 :  80 회,  8e-09
# 전체 진행도 :  90 회,  9e-09
# 전체 진행도 :  100 회,  1e-08
# 전체 진행도 :  110 회,  1.1e-08
# 전체 진행도 :  120 회,  1.2e-08
# 전체 진행도 :  130 회,  1.3e-08
# 전체 진행도 :  140 회,  1.4e-08
# 전체 진행도 :  150 회,  1.5e-08
# 전체 진행도 :  160 회,  1.6e-08
# 전체 진행도 :  170 회,  1.7e-08
# 전체 진행도 :  180 회,  1.8e-08
# 전체 진행도 :  190 회,  1.9e-08
# 전체 진행도 :  200 회,  2e-08
# 전체 진행도 :  210 회,  2.1e-08
# 전체 진행도 :  220 회,  2.2e-08
# 전체 진행도 :  230 회,  2.3e-08
# 전체 진행도 :  240 회,  2.4e-08
# 전체 진행도 :  250 회,  2.5e-08
# 전체 진행도 :  260 회,  2.6e-08
# 전체 진행도 :  270 회,  2.7e-08
# 전체 진행도 :  280 회,  2.8e-08
# 전체 진행도 :  290 회,  2.9e-08
# 전체 진행도 :  300 회,  3e-08
# 전체 진행도 :  310 회,  3.1e-08
# 전체 진행도 :  320 회,  3.2e-08
# 전체 진행도 :  330 회,  3.3e-08
# 전체 진행도 :  340 회,  3.4e-08
# 전체 진행도 :  350 회,  3.5e-08
# 전체 진행도 :  360 회,  3.6e-08
# ...
